# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample(5)
# Out:
# C:\Users\ashwin\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 690            0.297451          -0.053720          -0.155012
# 1938           0.266119          -0.007800          -0.103883
# 3761           0.286446          -0.024659          -0.036596
# 7238           0.282008          -0.015909          -0.107986
# 4494           0.318122          -0.030399          -0.131411
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 690          -0.897297         -0.748330         -0.540991         -0.916722
# 1938         -0.993779         -0.986155         -0.983133         -0.994507
# 3761          0.579778          0.583370         -0.177665          0.560552
# 7238         -0.995802         -0.993928         -0.989480         -0.996458
# 4494          0.006200         -0.059950         -0.314394         -0.011831
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  \
# 690          -0.753506         -0.594033         -0.763304
# 1938         -0.985771         -0.981819         -0.941981
# 3761          0.510154         -0.211612          0.620815
# 7238         -0.995025         -0.989846         -0.937351
# 4494         -0.144487         -0.317408          0.195661
#
#              ...          angle(tBodyAccMean,gravity)  \
# 690          ...                             0.007577
# 1938         ...                             0.011031
# 3761         ...                            -0.012164
# 7238         ...                            -0.384784
# 4494         ...                            -0.454398
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 690                               0.118384                         -0.510294
# 1938                             -0.281061                          0.114600
# 3761                             -0.643520                         -0.628323
# 7238                              0.366100                          0.247123
# 4494                              0.457877                         -0.706013
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 690                              -0.847207             -0.737200
# 1938                              0.446713             -0.554995
# 3761                             -0.261235             -0.759631
# 7238                             -0.070107              0.518823
# 4494                              0.493154             -0.773883
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity  \
# 690               0.095706             -0.172862        5         5
# 1938             -0.160464             -0.153113       11         4
# 3761              0.253517              0.078206       19         3
# 7238             -0.548759             -0.452500       30         6
# 4494              0.236428             -0.057284       22         1
#
#             ActivityName
# 690             STANDING
# 1938             SITTING
# 3761  WALKING_DOWNSTAIRS
# 7238              LAYING
# 4494             WALKING
#
# [5 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
# C:\Users\ashwin\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 943           0.286853          -0.022969          -0.092803
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 943         -0.946699         -0.778713         -0.970697         -0.954953
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 943         -0.799562         -0.972587         -0.914311      ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 943                    -0.151815                              0.113156
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 943                          0.389517                             -0.275689
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 943             -0.692129              -0.10304             -0.062471
#
#      subject  Activity  ActivityName
# 943       10         4       SITTING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_red = TSNE(verbose=2, perplexity=2).fit_transform(X_pre_tsne)
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.407s...
# [t-SNE] Computed neighbors for 7352 samples in 67.833s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.058s
# [t-SNE] Iteration 50: error = 124.7695618, gradient norm = 0.0265582 (50 iterations in 8.859s)
# [t-SNE] Iteration 100: error = 107.3876648, gradient norm = 0.0290282 (50 iterations in 6.002s)
# [t-SNE] Iteration 150: error = 101.0201569, gradient norm = 0.0218416 (50 iterations in 4.705s)
# [t-SNE] Iteration 200: error = 97.5996094, gradient norm = 0.0185092 (50 iterations in 4.633s)
# [t-SNE] Iteration 250: error = 95.2775421, gradient norm = 0.0136481 (50 iterations in 4.553s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.277542
# [t-SNE] Iteration 300: error = 4.1193829, gradient norm = 0.0015585 (50 iterations in 4.184s)
# [t-SNE] Iteration 350: error = 3.2110786, gradient norm = 0.0010017 (50 iterations in 4.054s)
# [t-SNE] Iteration 400: error = 2.7815824, gradient norm = 0.0007115 (50 iterations in 4.069s)
# [t-SNE] Iteration 450: error = 2.5181618, gradient norm = 0.0005649 (50 iterations in 4.038s)
# [t-SNE] Iteration 500: error = 2.3348875, gradient norm = 0.0004773 (50 iterations in 4.124s)
# [t-SNE] Iteration 550: error = 2.1972771, gradient norm = 0.0004179 (50 iterations in 4.126s)
# [t-SNE] Iteration 600: error = 2.0878544, gradient norm = 0.0003675 (50 iterations in 4.158s)
# [t-SNE] Iteration 650: error = 1.9978396, gradient norm = 0.0003314 (50 iterations in 4.213s)
# [t-SNE] Iteration 700: error = 1.9220251, gradient norm = 0.0003039 (50 iterations in 4.166s)
# [t-SNE] Iteration 750: error = 1.8570080, gradient norm = 0.0002763 (50 iterations in 4.145s)
# [t-SNE] Iteration 800: error = 1.8004071, gradient norm = 0.0002577 (50 iterations in 4.149s)
# [t-SNE] Iteration 850: error = 1.7506455, gradient norm = 0.0002376 (50 iterations in 4.163s)
# [t-SNE] Iteration 900: error = 1.7061807, gradient norm = 0.0002252 (50 iterations in 4.253s)
# [t-SNE] Iteration 950: error = 1.6661576, gradient norm = 0.0002138 (50 iterations in 4.152s)
# [t-SNE] Iteration 1000: error = 1.6298871, gradient norm = 0.0001976 (50 iterations in 4.102s)
# [t-SNE] KL divergence after 1000 iterations: 1.629887

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.558s...
# [t-SNE] Computed neighbors for 7352 samples in 68.749s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.058s
# [t-SNE] Iteration 50: error = 124.7818298, gradient norm = 0.0246982 (50 iterations in 8.225s)
# [t-SNE] Iteration 100: error = 107.0881500, gradient norm = 0.0291540 (50 iterations in 5.378s)
# [t-SNE] Iteration 150: error = 100.9069748, gradient norm = 0.0202987 (50 iterations in 4.409s)
# [t-SNE] Iteration 200: error = 97.5467606, gradient norm = 0.0154034 (50 iterations in 4.278s)
# [t-SNE] Iteration 250: error = 95.2557373, gradient norm = 0.0157471 (50 iterations in 4.253s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.255737
# [t-SNE] Iteration 300: error = 4.1207137, gradient norm = 0.0015636 (50 iterations in 4.002s)
# [t-SNE] Iteration 350: error = 3.2092614, gradient norm = 0.0009984 (50 iterations in 3.975s)
# [t-SNE] Iteration 400: error = 2.7799938, gradient norm = 0.0007152 (50 iterations in 4.096s)
# [t-SNE] Iteration 450: error = 2.5162482, gradient norm = 0.0005621 (50 iterations in 4.151s)
# [t-SNE] Iteration 500: error = 2.3330636, gradient norm = 0.0004773 (50 iterations in 4.171s)
# [t-SNE] Iteration 550: error = 2.1952884, gradient norm = 0.0004129 (50 iterations in 4.176s)
# [t-SNE] Iteration 600: error = 2.0857158, gradient norm = 0.0003666 (50 iterations in 4.169s)
# [t-SNE] Iteration 650: error = 1.9960018, gradient norm = 0.0003328 (50 iterations in 4.229s)
# [t-SNE] Iteration 700: error = 1.9201421, gradient norm = 0.0003046 (50 iterations in 4.097s)
# [t-SNE] Iteration 750: error = 1.8549889, gradient norm = 0.0002781 (50 iterations in 4.137s)
# [t-SNE] Iteration 800: error = 1.7984684, gradient norm = 0.0002527 (50 iterations in 4.231s)
# [t-SNE] Iteration 850: error = 1.7484897, gradient norm = 0.0002364 (50 iterations in 4.182s)
# [t-SNE] Iteration 900: error = 1.7037984, gradient norm = 0.0002243 (50 iterations in 4.455s)
# [t-SNE] Iteration 950: error = 1.6637394, gradient norm = 0.0002106 (50 iterations in 4.191s)
# [t-SNE] Iteration 1000: error = 1.6274045, gradient norm = 0.0002005 (50 iterations in 4.171s)
# [t-SNE] KL divergence after 1000 iterations: 1.627404
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.406s...
# [t-SNE] Computed neighbors for 7352 samples in 68.592s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.095s
# [t-SNE] Iteration 50: error = 114.2313690, gradient norm = 0.0164591 (50 iterations in 11.131s)
# [t-SNE] Iteration 100: error = 97.7537689, gradient norm = 0.0155595 (50 iterations in 4.957s)
# [t-SNE] Iteration 150: error = 93.3490753, gradient norm = 0.0107877 (50 iterations in 4.403s)
# [t-SNE] Iteration 200: error = 91.3630753, gradient norm = 0.0061935 (50 iterations in 4.293s)
# [t-SNE] Iteration 250: error = 90.1711426, gradient norm = 0.0058810 (50 iterations in 4.527s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.171143
# [t-SNE] Iteration 300: error = 3.5715194, gradient norm = 0.0014624 (50 iterations in 4.289s)
# [t-SNE] Iteration 350: error = 2.8138857, gradient norm = 0.0007542 (50 iterations in 4.239s)
# [t-SNE] Iteration 400: error = 2.4346406, gradient norm = 0.0005257 (50 iterations in 4.200s)
# [t-SNE] Iteration 450: error = 2.2177241, gradient norm = 0.0004078 (50 iterations in 4.184s)
# [t-SNE] Iteration 500: error = 2.0730653, gradient norm = 0.0003317 (50 iterations in 4.562s)
# [t-SNE] Iteration 550: error = 1.9680719, gradient norm = 0.0002833 (50 iterations in 4.730s)
# [t-SNE] Iteration 600: error = 1.8872527, gradient norm = 0.0002454 (50 iterations in 4.252s)
# [t-SNE] Iteration 650: error = 1.8222579, gradient norm = 0.0002200 (50 iterations in 4.271s)
# [t-SNE] Iteration 700: error = 1.7686983, gradient norm = 0.0001985 (50 iterations in 5.064s)
# [t-SNE] Iteration 750: error = 1.7234569, gradient norm = 0.0001815 (50 iterations in 5.333s)
# [t-SNE] Iteration 800: error = 1.6844113, gradient norm = 0.0001678 (50 iterations in 4.643s)
# [t-SNE] Iteration 850: error = 1.6505333, gradient norm = 0.0001542 (50 iterations in 4.995s)
# [t-SNE] Iteration 900: error = 1.6208900, gradient norm = 0.0001428 (50 iterations in 4.997s)
# [t-SNE] Iteration 950: error = 1.5943629, gradient norm = 0.0001330 (50 iterations in 4.374s)
# [t-SNE] Iteration 1000: error = 1.5706141, gradient norm = 0.0001245 (50 iterations in 4.593s)
# [t-SNE] KL divergence after 1000 iterations: 1.570614
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.410s...
# [t-SNE] Computed neighbors for 7352 samples in 73.123s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.186s
# [t-SNE] Iteration 50: error = 105.5250015, gradient norm = 0.0245820 (50 iterations in 7.915s)
# [t-SNE] Iteration 100: error = 90.3437042, gradient norm = 0.0100395 (50 iterations in 5.161s)
# [t-SNE] Iteration 150: error = 87.3152695, gradient norm = 0.0059665 (50 iterations in 4.621s)
# [t-SNE] Iteration 200: error = 86.0709534, gradient norm = 0.0037763 (50 iterations in 4.696s)
# [t-SNE] Iteration 250: error = 85.3698578, gradient norm = 0.0028595 (50 iterations in 4.750s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.369858
# [t-SNE] Iteration 300: error = 3.1290848, gradient norm = 0.0013828 (50 iterations in 5.446s)
# [t-SNE] Iteration 350: error = 2.4899473, gradient norm = 0.0006483 (50 iterations in 4.242s)
# [t-SNE] Iteration 400: error = 2.1698968, gradient norm = 0.0004218 (50 iterations in 4.271s)
# [t-SNE] Iteration 450: error = 1.9853965, gradient norm = 0.0003157 (50 iterations in 4.393s)
# [t-SNE] Iteration 500: error = 1.8677006, gradient norm = 0.0002501 (50 iterations in 4.596s)
# [t-SNE] Iteration 550: error = 1.7846062, gradient norm = 0.0002117 (50 iterations in 4.428s)
# [t-SNE] Iteration 600: error = 1.7219363, gradient norm = 0.0001809 (50 iterations in 4.361s)
# [t-SNE] Iteration 650: error = 1.6728294, gradient norm = 0.0001594 (50 iterations in 4.437s)
# [t-SNE] Iteration 700: error = 1.6329643, gradient norm = 0.0001440 (50 iterations in 4.360s)
# [t-SNE] Iteration 750: error = 1.6006933, gradient norm = 0.0001284 (50 iterations in 4.493s)
# [t-SNE] Iteration 800: error = 1.5736115, gradient norm = 0.0001248 (50 iterations in 4.380s)
# [t-SNE] Iteration 850: error = 1.5499706, gradient norm = 0.0001113 (50 iterations in 4.497s)
# [t-SNE] Iteration 900: error = 1.5297163, gradient norm = 0.0001036 (50 iterations in 5.503s)
# [t-SNE] Iteration 950: error = 1.5118232, gradient norm = 0.0000953 (50 iterations in 4.894s)
# [t-SNE] Iteration 1000: error = 1.4959855, gradient norm = 0.0000907 (50 iterations in 4.772s)
# [t-SNE] KL divergence after 1000 iterations: 1.495986
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.506s...
# [t-SNE] Computed neighbors for 7352 samples in 74.477s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.340s
# [t-SNE] Iteration 50: error = 97.9873810, gradient norm = 0.0144188 (50 iterations in 8.785s)
# [t-SNE] Iteration 100: error = 84.1854172, gradient norm = 0.0063274 (50 iterations in 6.401s)
# [t-SNE] Iteration 150: error = 82.0012283, gradient norm = 0.0068696 (50 iterations in 7.052s)
# [t-SNE] Iteration 200: error = 81.2491608, gradient norm = 0.0029211 (50 iterations in 5.591s)
# [t-SNE] Iteration 250: error = 80.8558121, gradient norm = 0.0017984 (50 iterations in 5.741s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.855812
# [t-SNE] Iteration 300: error = 2.6988184, gradient norm = 0.0013123 (50 iterations in 5.005s)
# [t-SNE] Iteration 350: error = 2.1635437, gradient norm = 0.0005745 (50 iterations in 4.699s)
# [t-SNE] Iteration 400: error = 1.9143018, gradient norm = 0.0003471 (50 iterations in 4.822s)
# [t-SNE] Iteration 450: error = 1.7683308, gradient norm = 0.0002462 (50 iterations in 4.782s)
# [t-SNE] Iteration 500: error = 1.6747085, gradient norm = 0.0001901 (50 iterations in 4.851s)
# [t-SNE] Iteration 550: error = 1.6103704, gradient norm = 0.0001564 (50 iterations in 4.770s)
# [t-SNE] Iteration 600: error = 1.5637068, gradient norm = 0.0001358 (50 iterations in 6.301s)
# [t-SNE] Iteration 650: error = 1.5284066, gradient norm = 0.0001188 (50 iterations in 4.805s)
# [t-SNE] Iteration 700: error = 1.5013107, gradient norm = 0.0001052 (50 iterations in 4.785s)
# [t-SNE] Iteration 750: error = 1.4802393, gradient norm = 0.0000965 (50 iterations in 4.918s)
# [t-SNE] Iteration 800: error = 1.4626833, gradient norm = 0.0000935 (50 iterations in 5.166s)
# [t-SNE] Iteration 850: error = 1.4494481, gradient norm = 0.0000883 (50 iterations in 4.928s)
# [t-SNE] Iteration 900: error = 1.4390856, gradient norm = 0.0000859 (50 iterations in 5.238s)
# [t-SNE] Iteration 950: error = 1.4309115, gradient norm = 0.0000802 (50 iterations in 4.793s)
# [t-SNE] Iteration 1000: error = 1.4236786, gradient norm = 0.0000780 (50 iterations in 4.895s)
# [t-SNE] KL divergence after 1000 iterations: 1.423679
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.488s...
# [t-SNE] Computed neighbors for 7352 samples in 77.725s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.817s
# [t-SNE] Iteration 50: error = 85.7530746, gradient norm = 0.0278039 (50 iterations in 8.806s)
# [t-SNE] Iteration 100: error = 75.4791107, gradient norm = 0.0036362 (50 iterations in 7.174s)
# [t-SNE] Iteration 150: error = 74.5855331, gradient norm = 0.0024092 (50 iterations in 6.732s)
# [t-SNE] Iteration 200: error = 74.2324371, gradient norm = 0.0019152 (50 iterations in 6.890s)
# [t-SNE] Iteration 250: error = 74.0535736, gradient norm = 0.0012048 (50 iterations in 6.926s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.053574
# [t-SNE] Iteration 300: error = 2.1489658, gradient norm = 0.0011780 (50 iterations in 6.565s)
# [t-SNE] Iteration 350: error = 1.7532325, gradient norm = 0.0004874 (50 iterations in 6.243s)
# [t-SNE] Iteration 400: error = 1.5864854, gradient norm = 0.0002781 (50 iterations in 6.246s)
# [t-SNE] Iteration 450: error = 1.4931130, gradient norm = 0.0001875 (50 iterations in 6.267s)
# [t-SNE] Iteration 500: error = 1.4330882, gradient norm = 0.0001395 (50 iterations in 6.224s)
# [t-SNE] Iteration 550: error = 1.3923155, gradient norm = 0.0001133 (50 iterations in 6.143s)
# [t-SNE] Iteration 600: error = 1.3639115, gradient norm = 0.0000960 (50 iterations in 6.372s)
# [t-SNE] Iteration 650: error = 1.3432494, gradient norm = 0.0000846 (50 iterations in 6.345s)
# [t-SNE] Iteration 700: error = 1.3283176, gradient norm = 0.0000741 (50 iterations in 6.303s)
# [t-SNE] Iteration 750: error = 1.3168238, gradient norm = 0.0000685 (50 iterations in 6.661s)
# [t-SNE] Iteration 800: error = 1.3077780, gradient norm = 0.0000655 (50 iterations in 6.336s)
# [t-SNE] Iteration 850: error = 1.3008772, gradient norm = 0.0000641 (50 iterations in 6.251s)
# [t-SNE] Iteration 900: error = 1.2954012, gradient norm = 0.0000595 (50 iterations in 6.206s)
# [t-SNE] Iteration 950: error = 1.2909305, gradient norm = 0.0000601 (50 iterations in 6.204s)
# [t-SNE] Iteration 1000: error = 1.2876829, gradient norm = 0.0000564 (50 iterations in 6.215s)
# [t-SNE] KL divergence after 1000 iterations: 1.287683
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']

# %%
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler().fit_transform(X_pre_tsne)
print(standardized_data.shape)
# Out:
# (7352, 561)

# %%
from sklearn import decomposition
pca = decomposition.PCA()

# %%
# configuring the parameteres
# the number of components = 2
pca.n_components = 2
pca_data = pca.fit_transform(standardized_data)

# pca_reduced will contain the 2-d projects of simple data
print("shape of pca_reduced.shape = ", pca_data.shape)
# Out:
# shape of pca_reduced.shape =  (7352, 2)

# %%
pca_data = np.vstack((pca_data.T, y_pre_tsne)).T
print(pca_data.shape)

# creating a new data fram which help us in ploting the result data
pca_df = pd.DataFrame(data=pca_data, columns=("1st_principal", "2nd_principal", "label"))
sns.FacetGrid(pca_df, hue="label", size=6).map(plt.scatter, '1st_principal', '2nd_principal').add_legend()
plt.show()
# Out:
# (7352, 3)
# C:\Users\ashwin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
